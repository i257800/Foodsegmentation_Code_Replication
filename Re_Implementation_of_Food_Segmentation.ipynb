# %% [markdown]
# # **Group Members:**
# **Hifza Umer (25i-7800)**
#
# **Ashifa Ikram (25i-7609)**

# %% [markdown]
# **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **unzip foodseg folder**

# %%
# !unzip -q /content/drive/MyDrive/foodseg.zip -d foodseg

# %%
# !ls foodseg/foodseg/
# Out:
# auto.py        occurrence-food103.npy	Readme.txt
# co-occa.ipynb  occurrence-recipe1M.npy	requirements.txt

# %%
# %cd foodseg/foodseg/
# Out:
# /content/foodseg/foodseg

# %%
# !pip install pytorch-lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 69.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# **installing required libraries**

# %%
import pytorch_lightning as pl
print(pl.__version__)
# Out:
# 2.6.0

# %%
# !pip install segmentation-models-pytorch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import segmentation_models_pytorch as smp
print(smp.__version__)
# Out:
# 0.5.0

# %%
# !python auto.py --encoder efficientnet-b0 --coocu True --decay 600 --matrix food103

# %% [markdown]
# **Dataset Downlloading link but  had already downloaded in my drive**

# %%
# !wget https://zenodo.org/records/15729578/files/FoodSeg103-256.zip
# Out:
# --2025-11-26 08:16:17--  https://zenodo.org/records/15729578/files/FoodSeg103-256.zip
# Resolving zenodo.org (zenodo.org)... 188.185.48.75, 137.138.52.235, 188.185.43.153, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1199113322 (1.1G) [application/octet-stream]
# Saving to: ‘FoodSeg103-256.zip’
#
# FoodSeg103-256.zip  100%[===================>]   1.12G  2.32MB/s    in 8m 0s
#
# 2025-11-26 08:24:18 (2.38 MB/s) - ‘FoodSeg103-256.zip’ saved [1199113322/1199113322]

# %%
# !unzip -q FoodSeg103-256.zip -d tmp

# %%
# !pip install grep
# !grep "==" /content/foodseg/foodseg/requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for grep: filename=grep-0.3.2-py3-none-any.whl size=2909 sha256=3daee74a3d22af8e324db8ba5bdcbb8396dfca2a263b2154f8dc549063da0b5d
#   Stored in directory: /root/.cache/pip/wheels/ac/63/0a/36e54c71cd4ec71f44911fc08126c0d91be2591bb842364a6a
# Successfully built grep
# ...
# albumentations==2.0.8
# numpy==2.3.1
# pandas==2.3.0
# Pillow==11.2.1
# pytorch_lightning==2.5.1
# segmentation_models_pytorch==0.5.0
# torch==2.6.0+cu126

# %% [markdown]
# # This Code Reproduce Complete results. I have attached some supporting files like co-occurance matrix .npy files and their code
